# %%
import pandas as pd

# %% [markdown]
# ## Задание 1
#  Напишите функцию, которая классифицирует фильмы из материалов занятия по следующим правилам:
# - оценка 2 и меньше - низкий рейтинг
# - оценка 4 и меньше - средний рейтинг
# - оценка 4.5 и 5 - высокий рейтинг

# %% [markdown]
# ### Мне показалось что классифицировать рейтинги пользователей как то не правильно поэтому я классифицировал рейтинги фильмов (потом сделал и задание)

# %%
ratings['rate_claccification'] = ratings['rating'].apply(rate_class)

# %%
ratings
# Out:
#         userId  movieId  rating   timestamp rate_claccification
# 0            1       31     2.5  1260759144     Средний рейтинг
# 1            1     1029     3.0  1260759179     Средний рейтинг
# 2            1     1061     3.0  1260759182     Средний рейтинг
# 3            1     1129     2.0  1260759185      Низкий рейтинг
# 4            1     1172     4.0  1260759205     Средний рейтинг
# ...        ...      ...     ...         ...                 ...
# 99999      671     6268     2.5  1065579370     Средний рейтинг
# 100000     671     6269     4.0  1065149201     Средний рейтинг
# 100001     671     6365     4.0  1070940363     Средний рейтинг
# 100002     671     6385     2.5  1070979663     Средний рейтинг
# 100003     671     6565     3.5  1074784724     Средний рейтинг
#
# [100004 rows x 5 columns]

# %%
movies = pd.read_csv('movies.csv')

# %%
movies
# Out:
#       movieId                                              title  \
# 0           1                                   Toy Story (1995)
# 1           2                                     Jumanji (1995)
# 2           3                            Grumpier Old Men (1995)
# 3           4                           Waiting to Exhale (1995)
# 4           5                 Father of the Bride Part II (1995)
# ...       ...                                                ...
# 9120   162672                                Mohenjo Daro (2016)
# 9121   163056                               Shin Godzilla (2016)
# 9122   163949  The Beatles: Eight Days a Week - The Touring Y...
# 9123   164977                           The Gay Desperado (1936)
# 9124   164979                              Women of '69, Unboxed
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# ...

# %%
ratings = pd.read_csv('ratings.csv')

# %%
ratings
# Out:
#         userId  movieId  rating   timestamp
# 0            1       31     2.5  1260759144
# 1            1     1029     3.0  1260759179
# 2            1     1061     3.0  1260759182
# 3            1     1129     2.0  1260759185
# 4            1     1172     4.0  1260759205
# ...        ...      ...     ...         ...
# 99999      671     6268     2.5  1065579370
# 100000     671     6269     4.0  1065149201
# 100001     671     6365     4.0  1070940363
# 100002     671     6385     2.5  1070979663
# 100003     671     6565     3.5  1074784724
#
# [100004 rows x 4 columns]

# %%
def rate_the_movie(input_movieId):
    """Высчитываем общую оценку фильма по оценкам из ratings"""
    
    return ratings[ratings.movieId == input_movieId].rating.mean()

# %%
rate_the_movie(671)
# Out:
# 4.03030303030303

# %%
movies['rate'] = movies['movieId'].apply(rate_the_movie)

# %%
movies
# Out:
#       movieId                                              title  \
# 0           1                                   Toy Story (1995)
# 1           2                                     Jumanji (1995)
# 2           3                            Grumpier Old Men (1995)
# 3           4                           Waiting to Exhale (1995)
# 4           5                 Father of the Bride Part II (1995)
# ...       ...                                                ...
# 9120   162672                                Mohenjo Daro (2016)
# 9121   163056                               Shin Godzilla (2016)
# 9122   163949  The Beatles: Eight Days a Week - The Touring Y...
# 9123   164977                           The Gay Desperado (1936)
# 9124   164979                              Women of '69, Unboxed
#
#                                            genres      rate
# 0     Adventure|Animation|Children|Comedy|Fantasy  3.872470
# 1                      Adventure|Children|Fantasy  3.401869
# ...

# %%
def rate_class(rate):
    """Классификация рейтинга фильма"""
    
    if rate <= 2:
        return('Низкий рейтинг')
    elif 4 >= rate > 2:
        return('Средний рейтинг')
    elif rate > 4:
        return('Высокий рейнинг')
    return('NaN')

# %%
movies['rate_classification'] = movies['rate'].apply(rate_class)

# %%
movies
# Out:
#       movieId                                              title  \
# 0           1                                   Toy Story (1995)
# 1           2                                     Jumanji (1995)
# 2           3                            Grumpier Old Men (1995)
# 3           4                           Waiting to Exhale (1995)
# 4           5                 Father of the Bride Part II (1995)
# ...       ...                                                ...
# 9120   162672                                Mohenjo Daro (2016)
# 9121   163056                               Shin Godzilla (2016)
# 9122   163949  The Beatles: Eight Days a Week - The Touring Y...
# 9123   164977                           The Gay Desperado (1936)
# 9124   164979                              Women of '69, Unboxed
#
#                                            genres      rate  \
# 0     Adventure|Animation|Children|Comedy|Fantasy  3.872470
# 1                      Adventure|Children|Fantasy  3.401869
# ...

# %% [markdown]
# ## Задание 2
#  Необходимо написать гео-классификатор, который каждой строке сможет выставить географическую принадлежность определенному региону. Т. е. если поисковый запрос содержит название города региона, то в столбце ‘region’ пишется название этого региона. Если поисковый запрос не содержит названия города, то ставим ‘undefined’.
#
# Правила распределения по регионам Центр, Северо-Запад и Дальний Восток:
#
# geo_data = {
#
# 'Центр': ['москва', 'тула', 'ярославль'],
#
# 'Северо-Запад': ['петербург', 'псков', 'мурманск'],
#
# 'Дальний Восток': ['владивосток', 'сахалин', 'хабаровск']
#
# }
#
# Результат классификации запишите в отдельный столбец region.

# %%
keywords = pd.read_csv('keywords.csv')

# %%
keywords
# Out:
#                        keyword     shows
# 0                           вк  64292779
# 1                одноклассники  63810309
# 2                        порно  41747114
# 3                         ютуб  39995567
# 4                    вконтакте  21014195
# ...                        ...       ...
# 99995   эльдорадо старый оскол      3705
# 99996      frigate для firefox      3630
# 99997                   укрсиб      3630
# 99998  погода в ялте на неделю      3688
# 99999                     ггму      3630
#
# [100000 rows x 2 columns]

# %%
geo_data = {

'Центр': ['москва', 'тула', 'ярославль'],

'Северо-Запад': ['петербург', 'псков', 'мурманск'],

'Дальний Восток': ['владивосток', 'сахалин', 'хабаровск']

}

# %%
def geo_clasification(keywords):
    """Выводим название региона если находим название города в запросе"""
    
    for key, values in geo_data.items():
        for value in values:
            if value in keywords:
                return key
    return "undefined"

# %%
keywords['region'] = keywords['keyword'].apply(geo_clasification)

# %%
keywords[keywords['region'] != "undefined"]
# Out:
#                                      keyword   shows          region
# 127                             авито москва  979292           Центр
# 370                 авито ру санкт петербург  425134    Северо-Запад
# 564                погода в санкт петербурге  292489    Северо-Запад
# 849                          авито ярославль  209581           Центр
# 1063                     фарпост владивосток  176951  Дальний Восток
# ...                                      ...     ...             ...
# 99590  авито ярославль автомобили с пробегом    3673           Центр
# 99634   северпост новости мурманской области    3606    Северо-Запад
# 99808      полармед мурманск запись на прием    3719    Северо-Запад
# 99890                    яндекс метро москва    4548           Центр
# 99922                      авто ру ярославль    3712           Центр
#
# [747 rows x 3 columns]

# %% [markdown]
# ## Или используем синтаксический сахар
# ## Upd. Не сообразил

# %%
lambda region:

# %%
keywords['region'] = keywords['keyword'].apply(lambda region: )

# %% [markdown]
# ## Задание 3
# Есть мнение, что “раньше снимали настоящее кино, не то что сейчас”. Ваша задача проверить это утверждение, используя файлы с рейтингами фильмов из прошлого домашнего занятия (файл movies.csv и ratings.csv из базы grouplens.org.../movielens). Т. е. проверить верно ли, что с ростом года выпуска фильма его средний рейтинг становится ниже.
#
# При этом мы не будем затрагивать субьективные факторы выставления этих рейтингов, а пройдемся по следующему алгоритму:
#
#     В переменную years запишите список из всех годов с 1950 по 2010.
#
#     Напишите функцию production_year, которая каждой строке из названия фильма выставляет год выпуска. Не все названия фильмов содержат год выпуска в одинаковом формате, поэтому используйте следующий алгоритм:
#         для каждой строки пройдите по всем годам списка years
#         если номер года присутствует в названии фильма, то функция возвращает этот год как год выпуска
#         если ни один из номеров года списка years не встретился в названии фильма, то возвращается 1900 год
#
#     Запишите год выпуска фильма по алгоритму пункта 2 в новый столбец ‘year’
#
#     Посчитайте средний рейтинг всех фильмов для каждого значения столбца ‘year’ и отсортируйте результат по убыванию рейтинга
#
# P/S/ все файлы находятся в архиве «дополнительные файлы к лекции и дз»

# %%
years = list(range(1950, 2011, 1))

# %% [markdown]
# ## Как по мне сделал бы на регуляре

# %%
def production_year(title):
    """Находим год выпуска фильма вписанный в имя фильма"""
    
    for year in years:
        if str(year) in title:
            return year
    return "1900"

# %%
movies['year'] = movies['title'].apply(production_year)

# %%
movies
# Out:
#       movieId                                              title  \
# 0           1                                   Toy Story (1995)
# 1           2                                     Jumanji (1995)
# 2           3                            Grumpier Old Men (1995)
# 3           4                           Waiting to Exhale (1995)
# 4           5                 Father of the Bride Part II (1995)
# ...       ...                                                ...
# 9120   162672                                Mohenjo Daro (2016)
# 9121   163056                               Shin Godzilla (2016)
# 9122   163949  The Beatles: Eight Days a Week - The Touring Y...
# 9123   164977                           The Gay Desperado (1936)
# 9124   164979                              Women of '69, Unboxed
#
#                                            genres  year
# 0     Adventure|Animation|Children|Comedy|Fantasy  1995
# 1                      Adventure|Children|Fantasy  1995
# ...

# %% [markdown]
# ## Нашел ошибку так как в датафрейме присутсвуют фильмы с годом выпуска позже 2010

# %%
years = list(range(1950, 2017, 1))

# %%
movies
# Out:
#       movieId                                              title  \
# 0           1                                   Toy Story (1995)
# 1           2                                     Jumanji (1995)
# 2           3                            Grumpier Old Men (1995)
# 3           4                           Waiting to Exhale (1995)
# 4           5                 Father of the Bride Part II (1995)
# ...       ...                                                ...
# 9120   162672                                Mohenjo Daro (2016)
# 9121   163056                               Shin Godzilla (2016)
# 9122   163949  The Beatles: Eight Days a Week - The Touring Y...
# 9123   164977                           The Gay Desperado (1936)
# 9124   164979                              Women of '69, Unboxed
#
#                                            genres  year      rate
# 0     Adventure|Animation|Children|Comedy|Fantasy  1995  3.872470
# ...

# %%
def rate_of_year(year):
    """Средний рейтинг фильмов за год"""
    
    return movies[movies['year'] == year].rate.mean()

# %%
year_rating = pd.DataFrame({'years': years})

# %%
year_rating['year_rating'] = year_rating['years'].apply(rate_of_year)

# %%
year_rating.sort_values('year_rating', ascending=False)
# Out:
#     years  year_rating
# 1    1951     3.906653
# 2    1952     3.802318
# 12   1962     3.772962
# 3    1953     3.738878
# 7    1957     3.693322
# ..    ...          ...
# 51   2001     3.133080
# 62   2012     3.061191
# 65   2015     3.000008
# 66   2016     2.996714
# 64   2014     2.966322
#
# [67 rows x 2 columns]
