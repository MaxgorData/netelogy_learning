# %%
import pandas as pd
import numpy as np
import re

# %% [markdown]
# ## Задание 1. Загрузка данных
# Изучить представленный набор данных на основе описания его столбцов, загрузить его и оставить 8 столбцов для дальнейшего изучения: surgery?, Age, rectal temperature, pulse, respiratory rate, temperature of extremities, pain, outcome.

# %%
horse_colums = ['surgery?', 'Age', 'rectal temperature', 'pulse', 'respiratory rate', 'temperature of extremities', 'pain', 'outcome']

# %%
horse_db = pd.read_csv('horse_data.csv', na_values='?')
horse_db.head(30)
# Out:
#       2  1   530101  38.50     66    28    3  3.1    ?  2.1  ...  45.00  8.40  \
# 0   1.0  1   534817   39.2   88.0  20.0  NaN  NaN  4.0  1.0  ...   50.0  85.0
# 1   2.0  1   530334   38.3   40.0  24.0  1.0  1.0  3.0  1.0  ...   33.0   6.7
# 2   1.0  9  5290409   39.1  164.0  84.0  4.0  1.0  6.0  2.0  ...   48.0   7.2
# 3   2.0  1   530255   37.3  104.0  35.0  NaN  NaN  6.0  2.0  ...   74.0   7.4
# 4   2.0  1   528355    NaN    NaN   NaN  2.0  1.0  3.0  1.0  ...    NaN   NaN
# 5   1.0  1   526802   37.9   48.0  16.0  1.0  1.0  1.0  1.0  ...   37.0   7.0
# 6   1.0  1   529607    NaN   60.0   NaN  3.0  NaN  NaN  1.0  ...   44.0   8.3
# 7   2.0  1   530051    NaN   80.0  36.0  3.0  4.0  3.0  1.0  ...   38.0   6.2
# 8   2.0  9  5299629   38.3   90.0   NaN  1.0  NaN  1.0  1.0  ...   40.0   6.2
# 9   1.0  1   528548   38.1   66.0  12.0  3.0  3.0  5.0  1.0  ...   44.0   6.0
# 10  2.0  1   527927   39.1   72.0  52.0  2.0  NaN  2.0  1.0  ...   50.0   7.8
# ...

# %%
f = open('horse_data.names', 'r')
horse_data = f.readlines()
f.close()
horse_data
# Out:
# ['1. TItle: Horse Colic database\n',
#  '\n',
#  '2. Source Information\n',
#  '   -- Creators: Mary McLeish & Matt Cecile\n',
#  '\t  \tDepartment of Computer Science\n',
#  '\t\tUniversity of Guelph\n',
#  '\t\tGuelph, Ontario, Canada N1G 2W1\n',
#  '\t\tmdmcleish@water.waterloo.edu\n',
#  '   -- Donor:    Will Taylor (taylor@pluto.arc.nasa.gov)\n',
#  '   -- Date:     8/6/89\n',
#  '\n',
#  '3. Past Usage:\n',
#  '   -- Unknown\n',
#  '\n',
#  '4. Relevant Information:\n',
#  '\n',
#  '   -- 2 data files\n',
#  '      -- horse-colic.data: 300 training instances\n',
#  '      -- horse-colic.test: 68 test instances\n',
#  '   -- Possible class attributes: 24 (whether lesion is surgical)\n',
#  '     -- others include: 23, 25, 26, and 27\n',
#  '   -- Many Data types: (continuous, discrete, and nominal)\n',
#  '\n',
#  '5. Number of Instances: 368 (300 for training, 68 for testing)\n',
#  '\n',
#  '6. Number of attributes: 28\n',
#  '\n',
#  '7. Attribute Information:\n',
#  '\n',
# ...

# %%
def colums_for_df(horse_data):
    """Принимает текст и выводит пронумерованный словарь названий колонок"""
    re_horse = []
    horse_names_colums = {}
    horse_colums = {}
    
    for line in horse_data:
        find = re.findall(r'\d\:\s+(\w+)', line)
        if find:
            re_horse.append(re.findall(r'\d+\:\s+.+', line))
    
    for string in re_horse:
        ind = re.search(r'\d+', string[0])
        colum = re.findall(r'\d\:\s+(.+)', string[0])[0]
        for i in range(1,29):
            if i == int(ind[0]):
                horse_names_colums[i] = colum
    
    for i in range(1,29):
        if i in list(horse_names_colums.keys()):
            horse_colums[i] = horse_names_colums[i]
        else:
            horse_colums[i] = i
    
    return horse_colums

# %%
horse_dirt = colums_for_df(horse_data)
print(list(horse_dirt.values()))
# Out:
# ['surgery?', 'Age', 'Hospital Number', 'rectal temperature', 'pulse', 'respiratory rate', 'temperature of extremities', 'peripheral pulse', 'mucous membranes', 'capillary refill time', "pain - a subjective judgement of the horse's pain level", 'peristalsis', 'abdominal distension', 'nasogastric tube', 'nasogastric reflux', 'nasogastric reflux PH', 'rectal examination - feces', 'abdomen', 'packed cell volume', 'total protein', 'abdominocentesis appearance', 'abdomcentesis total protein', 'outcome', 'surgical lesion?', 25, 26, 'type of lesion', 'cp_data']

# %%
list(horse_db.columns)
# Out:
# ['2',
#  '1',
#  '530101',
#  '38.50',
#  '66',
#  '28',
#  '3',
#  '3.1',
#  '?',
#  '2.1',
#  '5',
#  '4',
#  '4.1',
#  '?.1',
#  '?.2',
#  '?.3',
#  '3.2',
#  '5.1',
#  '45.00',
#  '8.40',
#  '?.4',
#  '?.5',
#  '2.2',
#  '2.3',
#  '11300',
#  '00000',
#  '00000.1',
#  '2.4']

# %%
list_of_colums = list(colums_for_df(horse_data).values())
list_of_colums = [
 'surgery',
 'age',
 'hospital_number',
 'rectal_temperature',
 'pulse',
 'respiratory_rate',
 'temperature_of_extremities',
 'peripheral_pulse',
 'mucous_membranes',
 'capillary_refill_time',
 'pain',
 'peristalsis',
 'abdominal_distension',
 'nasogastric_tube',
 'nasogastric_reflux',
 'nasogastric_reflux_ph',
 'rectal_examination',
 'abdomen',
 'packed_cell_volume',
 'total_protein',
 'abdominocentesis_appearance',
 'abdomcentesis_total_protein',
 'outcome',
 'surgical_lesion',
 25,
 26,
 'type_of_lesion',
 'cp_data']
list_of_colums
# Out:
# ['surgery',
#  'age',
#  'hospital_number',
#  'rectal_temperature',
#  'pulse',
#  'respiratory_rate',
#  'temperature_of_extremities',
#  'peripheral_pulse',
#  'mucous_membranes',
#  'capillary_refill_time',
#  'pain',
#  'peristalsis',
#  'abdominal_distension',
#  'nasogastric_tube',
#  'nasogastric_reflux',
#  'nasogastric_reflux_ph',
#  'rectal_examination',
#  'abdomen',
#  'packed_cell_volume',
#  'total_protein',
#  'abdominocentesis_appearance',
#  'abdomcentesis_total_protein',
#  'outcome',
#  'surgical_lesion',
#  25,
#  26,
#  'type_of_lesion',
#  'cp_data']

# %%
horse_db_colums = {}
for i, colume in enumerate(horse_db.columns):
    horse_db_colums[colume] = list_of_colums[i]
print(horse_db_colums)
# Out:
# {'2': 'surgery', '1': 'age', '530101': 'hospital_number', '38.50': 'rectal_temperature', '66': 'pulse', '28': 'respiratory_rate', '3': 'temperature_of_extremities', '3.1': 'peripheral_pulse', '?': 'mucous_membranes', '2.1': 'capillary_refill_time', '5': 'pain', '4': 'peristalsis', '4.1': 'abdominal_distension', '?.1': 'nasogastric_tube', '?.2': 'nasogastric_reflux', '?.3': 'nasogastric_reflux_ph', '3.2': 'rectal_examination', '5.1': 'abdomen', '45.00': 'packed_cell_volume', '8.40': 'total_protein', '?.4': 'abdominocentesis_appearance', '?.5': 'abdomcentesis_total_protein', '2.2': 'outcome', '2.3': 'surgical_lesion', '11300': 25, '00000': 26, '00000.1': 'type_of_lesion', '2.4': 'cp_data'}

# %%
horse_db.rename(columns=horse_db_colums, inplace=True)
horse_db.head(5)
# Out:
#    surgery  age  hospital_number  rectal_temperature  pulse  respiratory_rate  \
# 0      1.0    1           534817                39.2   88.0              20.0
# 1      2.0    1           530334                38.3   40.0              24.0
# 2      1.0    9          5290409                39.1  164.0              84.0
# 3      2.0    1           530255                37.3  104.0              35.0
# 4      2.0    1           528355                 NaN    NaN               NaN
#
#    temperature_of_extremities  peripheral_pulse  mucous_membranes  \
# 0                         NaN               NaN               4.0
# 1                         1.0               1.0               3.0
# 2                         4.0               1.0               6.0
# 3                         NaN               NaN               6.0
# 4                         2.0               1.0               3.0
#
#    capillary_refill_time  ...  packed_cell_volume  total_protein  \
# ...

# %%
horse_colums = ['surgery', 'age', 'rectal_temperature', 'pulse', 'respiratory_rate', 'temperature_of_extremities', 'pain', 'outcome']

# %%
filtered_horse_db = horse_db.loc[:, horse_colums]
filtered_horse_db.tail(15)
# Out:
#      surgery  age  rectal_temperature  pulse  respiratory_rate  \
# 284      1.0    1                38.5   66.0              24.0
# 285      2.0    1                37.8   82.0              12.0
# 286      2.0    9                39.5   84.0              30.0
# 287      1.0    1                 NaN    NaN               NaN
# 288      1.0    1                38.0   50.0              36.0
# 289      2.0    1                38.6   45.0              16.0
# 290      1.0    1                38.9   80.0              44.0
# 291      1.0    1                37.0   66.0              20.0
# 292      1.0    1                 NaN   78.0              24.0
# 293      2.0    1                38.5   40.0              16.0
# 294      1.0    1                 NaN  120.0              70.0
# 295      2.0    1                37.2   72.0              24.0
# 296      1.0    1                37.5   72.0              30.0
# 297      1.0    1                36.5  100.0              24.0
# ...

# %% [markdown]
# ## Задание 2. Первичное изучение данных
# Проанализировать значения по столбцам, рассчитать базовые статистики, найти выбросы.

# %%
filtered_horse_db.describe()
# Out:
#           surgery        age  rectal_temperature       pulse  \
# count  298.000000  299.00000          239.000000  275.000000
# mean     1.395973    1.64214           38.166527   71.934545
# std      0.489881    2.17730            0.733508   28.680522
# min      1.000000    1.00000           35.400000   30.000000
# 25%      1.000000    1.00000           37.800000   48.000000
# 50%      1.000000    1.00000           38.200000   64.000000
# 75%      2.000000    1.00000           38.500000   88.000000
# max      2.000000    9.00000           40.800000  184.000000
#
#        respiratory_rate  temperature_of_extremities        pain     outcome
# count        241.000000                  243.000000  244.000000  298.000000
# mean          30.427386                    2.345679    2.942623    1.550336
# std           17.678256                    1.046369    1.303993    0.737967
# min            8.000000                    1.000000    1.000000    1.000000
# ...

# %%
filtered_horse_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   surgery                     298 non-null    float64
#  1   age                         299 non-null    int64
#  2   rectal_temperature          239 non-null    float64
#  3   pulse                       275 non-null    float64
#  4   respiratory_rate            241 non-null    float64
#  5   temperature_of_extremities  243 non-null    float64
#  6   pain                        244 non-null    float64
#  7   outcome                     298 non-null    float64
# dtypes: float64(7), int64(1)
# memory usage: 18.8 KB

# %%
for column in filtered_horse_db.columns:
    print(column)
    q1 = filtered_horse_db[column].quantile(0.25)
    q3 = filtered_horse_db[column].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - (1.5 * iqr) 
    upper_bound = q3 + (1.5 * iqr)
    blowouts = filt_horse_db.loc[~filtered_horse_db[column].between(lower_bound, upper_bound, inclusive=True), column].dropna()
    print(blowouts)
# Out:
# surgery
# Series([], Name: surgery, dtype: float64)
# age
# 2      9
# 8      9
# 12     9
# 15     9
# 22     9
# 38     9
# 40     9
# 54     9
# 73     9
# 74     9
# 81     9
# 102    9
# 108    9
# 134    9
# 190    9
# 211    9
# 226    9
# 228    9
# 243    9
# 251    9
# 254    9
# 261    9
# 274    9
# 286    9
# Name: age, dtype: int64
# rectal_temperature
# 19     39.9
# 43     35.4
# 53     40.3
# 74     39.7
# 79     36.4
# 90     40.3
# 98     39.6
# 117    36.5
# 140    36.0
# 237    36.1
# 250    36.6
# 258    40.8
# 280    40.0
# 297    36.5
# Name: rectal_temperature, dtype: float64
# pulse
# 2      164.0
# 40     150.0
# 54     160.0
# 254    184.0
# 274    150.0
# Name: pulse, dtype: float64
# respiratory_rate
# 2      84.0
# 38     96.0
# 40     72.0
# 81     80.0
# 83     80.0
# 102    68.0
# 105    96.0
# 119    66.0
# 124    68.0
# 185    90.0
# 207    80.0
# 228    70.0
# 243    88.0
# 254    84.0
# 264    68.0
# 268    90.0
# 294    70.0
# ...

# %% [markdown]
# ### Изучаем данные по выбросам
# * surgery В первой колонке помощь не присутствует выбросов, только одно пропущенное значение.
# * age Во второй колонке присутствуют только значения 9 и 1, значит была допущена ошибка при которой взрослую лошадь (больше 6 месяцев) обзначают значением 9. Изменяем 9 на 2 для обозначения взрослой особи руководствуясь описанием датафрейма (horse_data.names)
# * rectal_temperature есть высокие значения но в допустимых пределах для больной лошади (прогуглено)
# * pulse значения столбца пульс тоже возможны, выбросов нет
# * respiratory_rate аналогично
# * temperature_of_extremities выбросов не присутствует
# * pain аналогично
# * outcome аналогично

# %%
filtered_horse_db.loc[~(filtered_horse_db.age == 9)]
# Out:
#      surgery  age  rectal_temperature  pulse  respiratory_rate  \
# 0        1.0    1                39.2   88.0              20.0
# 1        2.0    1                38.3   40.0              24.0
# 3        2.0    1                37.3  104.0              35.0
# 4        2.0    1                 NaN    NaN               NaN
# 5        1.0    1                37.9   48.0              16.0
# 6        1.0    1                 NaN   60.0               NaN
# 7        2.0    1                 NaN   80.0              36.0
# 9        1.0    1                38.1   66.0              12.0
# 10       2.0    1                39.1   72.0              52.0
# 11       1.0    1                37.2   42.0              12.0
# 13       1.0    1                38.2   76.0              28.0
# 14       1.0    1                37.6   96.0              48.0
# 16       2.0    1                37.5   48.0              24.0
# 17       1.0    1                37.6   64.0              21.0
# ...

# %%
filtered_horse_db.loc[(filtered_horse_db.age == 9), 'age'] = 2
filtered_horse_db
# Out:
#      surgery  age  rectal_temperature  pulse  respiratory_rate  \
# 0        1.0    1                39.2   88.0              20.0
# 1        2.0    1                38.3   40.0              24.0
# 2        1.0    2                39.1  164.0              84.0
# 3        2.0    1                37.3  104.0              35.0
# 4        2.0    1                 NaN    NaN               NaN
# 5        1.0    1                37.9   48.0              16.0
# 6        1.0    1                 NaN   60.0               NaN
# 7        2.0    1                 NaN   80.0              36.0
# 8        2.0    2                38.3   90.0               NaN
# 9        1.0    1                38.1   66.0              12.0
# 10       2.0    1                39.1   72.0              52.0
# 11       1.0    1                37.2   42.0              12.0
# 12       2.0    2                38.0   92.0              28.0
# 13       1.0    1                38.2   76.0              28.0
# ...

# %% [markdown]
# ## Задание 3.  Работа с пропусками
# Рассчитать количество пропусков для всех выбранных столбцов. Принять и обосновать решение о методе заполнения пропусков по каждому столбцу на основе рассчитанных статистик и возможной взаимосвязи значений в них. Сформировать датафрейм, в котором пропуски будут отсутствовать.

# %%
filtered_horse_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   surgery                     298 non-null    float64
#  1   age                         299 non-null    int64
#  2   rectal_temperature          239 non-null    float64
#  3   pulse                       275 non-null    float64
#  4   respiratory_rate            241 non-null    float64
#  5   temperature_of_extremities  243 non-null    float64
#  6   pain                        244 non-null    float64
#  7   outcome                     298 non-null    float64
# dtypes: float64(7), int64(1)
# memory usage: 18.8 KB

# %%
(filtered_horse_db.isna().mean() * 100).round(2)
# Out:
# surgery                        0.33
# age                            0.00
# rectal_temperature            20.07
# pulse                          8.03
# respiratory_rate              19.40
# temperature_of_extremities    18.73
# pain                          18.39
# outcome                        0.33
# dtype: float64

# %% [markdown]
# ### Рассмотрим и подумаем над пропусками в данных
#
# * surgery Наличие операции (1 пропущенный) - крайне важная метрика, удалим строки с пропущенными данными
# * age Возраст - нет ни одного пропущенного
# * rectal_temperature Ректальная температура (60 пропущено) - важная метрика, строки с пропущенными данными удалим
# * pulse  Пульс (24 пропущено) - важная метрика, строки с пропущенными данными удалим
# * respiratory_rate  Частота дыхания (58 пропущено) - важная метрика, строки с пропущенными данными удалим
# * temperature_of_extremities [ нормальные теплые холодные ледяные ]  Температура конечностей (56 пропущено) - субъективная метрика (из описания датафрейма определяется ветеринаром), которая так же может исказиться как тревожностью лошади, физиологическими особенностями, полом так и человеческим фактором. Заполняем пропуски средними значениями
# * pain Уровень боли (55 пропущено) - такая же субъективная метрика (из описания датафрейма определяется ветеринаром), которая может исказиться как тревожностью лошади, физиологическими особенностями, полом так и человеческим фактором. Принимаем за пропуски за 0 так как скорее всего боль лошади не привлекла внимания у наблюдающего
# * outcome Исход (1 пропущенный) - предполагаю что в той же записи что и пропущенная наличие операции - удалим пропущенное

# %%
horse_db_droppedna = filtered_horse_db.dropna(subset=['surgery', 'rectal_temperature', 'pulse', 'respiratory_rate',
                                                  'outcome'])

# %%
horse_db_droppedna.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 205 entries, 0 to 298
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   surgery                     205 non-null    float64
#  1   age                         205 non-null    int64
#  2   rectal_temperature          205 non-null    float64
#  3   pulse                       205 non-null    float64
#  4   respiratory_rate            205 non-null    float64
#  5   temperature_of_extremities  168 non-null    float64
#  6   pain                        168 non-null    float64
#  7   outcome                     205 non-null    float64
# dtypes: float64(7), int64(1)
# memory usage: 14.4 KB

# %%
normal_temperature = horse_db_droppedna['temperature_of_extremities'].mean().round(0)
normal_temperature
# Out:
# 2.0

# %% [markdown]
# ## = теплые конечности

# %%
horse_db_droppedna['temperature_of_extremities'].fillna(normal_temperature, inplace=True)
# Out:
# /tmp/ipykernel_4677/1489956737.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   horse_db_droppedna['temperature_of_extremities'].fillna(normal_temperature, inplace=True)

# %%
horse_db_droppedna['pain'].fillna(0, inplace=True)
# Out:
# /tmp/ipykernel_4677/350684533.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   horse_db_droppedna['pain'].fillna(0, inplace=True)

# %%
horse_db_droppedna.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 205 entries, 0 to 298
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   surgery                     205 non-null    float64
#  1   age                         205 non-null    int64
#  2   rectal_temperature          205 non-null    float64
#  3   pulse                       205 non-null    float64
#  4   respiratory_rate            205 non-null    float64
#  5   temperature_of_extremities  205 non-null    float64
#  6   pain                        205 non-null    float64
#  7   outcome                     205 non-null    float64
# dtypes: float64(7), int64(1)
# memory usage: 14.4 KB
